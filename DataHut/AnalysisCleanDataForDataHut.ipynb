# %% [markdown]
# ### Assignment for Data QA & QC Internship @ Datahut

# %% [markdown]
# DataSet Messy_data Source(https://www.dropbox.com/scl/fi/qxjv1jjosw1eueouv7v1w/messy_data.csv?rlkey=9qu8bsjd4wgi6rz0br4hrudjd&st=9ngzdwui&dl=1)

# %% [markdown]
# Dataset contain details of Employees, their age, their mail Id , Joining date, Salary and to which department they belong
# ##### Objective: Clean up the dataset and ensure it is ready for analysis

# %% [markdown]
# ****
# ## 1. Load the Data:
# ****

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\naasa\\OneDrive\\Desktop\\Nahi\\Internship\\DataHut\\messy_data.csv")

# %%
df
# Out:
#        Unnamed: 0                                    ID  \
# 0               0  1e407ff9-6255-489d-a0de-34135d4f74bd
# 1               1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2               2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3               3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 4               4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90
# ...           ...                                   ...
# 10995        6523  07c223be-03e6-4f70-a2b5-86df778cc61a
# 10996        9785  da8a6bbc-5026-4630-848d-f64e80dac56c
# 10997        7826  ed19c966-d6d8-4047-b410-b6e595a39340
# 10998        7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
# 10999        7107  fc25a38a-5747-46eb-b6d3-7173f8255809
#
#                           Name   Age                      Email   Join Date  \
# 0                Hunter Thomas  25.0         xlopez@hotmail.com         NaN
# 1                 Jeremy Irwin  90.0            Jillian Jenkins  2022-07-07
# ...

# %% [markdown]
# ****
# ## 2. Inspect the Data:
# ****

# %%
print(df.shape)
# Out:
# (11000, 8)

# %% [markdown]
# **Dimension of the dataset: Their are 11000 rows and 8 coloumns**

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Email', 'Join Date', 'Salary',
#        'Department'],
#       dtype='object')

# %% [markdown]
# **Names of the columns in dataset: 'Unnamed: 0', 'ID', 'Name', 'Age', 'Email', 'Join Date', 'Salary',  'Department**'

# %%
df['ID'].value_counts()
# Out:
# ID
# 0413800c-975f-4107-908c-f9f733496b3c    2
# 4bef5bf5-199e-4d39-bce3-4a32ddc8a3bc    2
# ec65b3d4-3af4-4de4-92a6-89ca4ce68a8f    2
# 17c94cd6-c896-451f-9452-7b8b2f2f8105    2
# 9700d4d3-1fc8-4837-ad68-087f26458e2f    2
#                                        ..
# 975fdc98-fc44-4b30-aa72-e098fb41edf8    1
# 93244314-ce92-47f6-9ec3-4334bb700438    1
# 1e0849fc-9ca7-4643-9536-3d358cd4b2f0    1
# ed51f499-85c2-42c8-8901-b1c0ee7c3ad2    1
# ae6eee4d-ca8f-4932-96f1-487230875968    1
# Name: count, Length: 10000, dtype: int64

# %%
df['Unnamed: 0'].value_counts()
# Out:
# Unnamed: 0
# 8410    2
# 8714    2
# 9283    2
# 4093    2
# 4598    2
#        ..
# 3491    1
# 3492    1
# 3493    1
# 3494    1
# 9999    1
# Name: count, Length: 10000, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Support        1425
# Sales          1422
# Marketing      1422
# Engineering    1353
# HR             1349
#                ...
# HRc               2
# SupportN          1
# HRx               1
# SupportH          1
# MarketingA        1
# Name: count, Length: 264, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  11000 non-null  int64
#  1   ID          11000 non-null  object
#  2   Name        8667 non-null   object
#  3   Age         9253 non-null   float64
#  4   Email       9731 non-null   object
#  5   Join Date   8808 non-null   object
#  6   Salary      8761 non-null   float64
#  7   Department  8745 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 687.6+ KB

# %% [markdown]
# **Observation:**
# 1. Unnamed: 0 seem to be used for indexing
# 2. need to check if there is any common rows in id and unnamed 0 and Name
# 3. Join date is now object

# %%
df = df.rename(columns={'Unnamed: 0': 'Serial No'})

# %% [markdown]
# ****
# ## 3. Standardise Date Formats:
# ****

# %%
df['Join Date'] = pd.to_datetime(df['Join Date'], errors='coerce')

# %%
df
# Out:
#        Serial No                                    ID  \
# 0              0  1e407ff9-6255-489d-a0de-34135d4f74bd
# 1              1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2              2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3              3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 4              4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90
# ...          ...                                   ...
# 10995       6523  07c223be-03e6-4f70-a2b5-86df778cc61a
# 10996       9785  da8a6bbc-5026-4630-848d-f64e80dac56c
# 10997       7826  ed19c966-d6d8-4047-b410-b6e595a39340
# 10998       7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
# 10999       7107  fc25a38a-5747-46eb-b6d3-7173f8255809
#
#                           Name   Age                      Email  Join Date  \
# 0                Hunter Thomas  25.0         xlopez@hotmail.com        NaT
# 1                 Jeremy Irwin  90.0            Jillian Jenkins 2022-07-07
# 2      Jennifer Hammondquickly  66.0            jscottgreen.biz 2023-11-21
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Serial No   11000 non-null  int64
#  1   ID          11000 non-null  object
#  2   Name        8667 non-null   object
#  3   Age         9253 non-null   float64
#  4   Email       9731 non-null   object
#  5   Join Date   6990 non-null   datetime64[ns]
#  6   Salary      8761 non-null   float64
#  7   Department  8745 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 687.6+ KB

# %% [markdown]
# ****
# ## 4. Correct Department Names:
# ****

# %%
df['Department'].unique()
# Out:
# array(['Sales', nan, 'Engineering', 'SupportJ', 'Marketing', 'SupportE',
#        'HR', 'Support', 'HRC', 'SalesA', 'SalesX', 'Supportu',
#        'Engineeringi', 'MarketingR', 'Salesw', 'SalesK', 'MarketingU',
#        'Salesi', 'HRa', 'SalesG', 'Supporty', 'SalesN', 'Marketinge',
#        'Marketingv', 'HRv', 'SalesM', 'EngineeringL', 'MarketingQ', 'HRs',
#        'SalesW', 'Supportj', 'Salesd', 'Marketingu', 'Engineeringj',
#        'SalesU', 'HRO', 'MarketingH', 'Salesj', 'Saleso', 'SalesZ',
#        'Engineeringe', 'MarketingF', 'Marketingr', 'Engineeringm', 'HRW',
#        'HRt', 'HRz', 'Engineeringp', 'HRF', 'EngineeringS', 'SupportW',
#        'EngineeringT', 'SalesC', 'SalesB', 'SupportC', 'SalesY',
#        'Marketingn', 'EngineeringK', 'Marketingz', 'HRo', 'SupportB',
#        'HRi', 'Salest', 'Supportg', 'Supporta', 'HRn', 'SupportQ',
#        'Salesr', 'EngineeringG', 'Supportm', 'Supporto', 'EngineeringH',
# ...

# %%
# Standardize 'Department' values for Sales and Support
df.loc[df['Department'].str.match(r'^Sales.*', na=False), 'Department'] = 'Sales'
df.loc[df['Department'].str.match(r'^Engineering.*', na=False), 'Department'] = 'Engineering'
df.loc[df['Department'].str.match(r'^Support.*', na=False), 'Department'] = 'Support'
df.loc[df['Department'].str.match(r'^HR.*', na=False), 'Department'] = 'HR'
df.loc[df['Department'].str.match(r'^Marketing.*', na=False), 'Department'] = 'Marketing'
df.loc[df['Department'].str.match(r'^Marketing.*', na=False), 'Department'] = 'Marketing'

# %%
df['Department'].unique()
# Out:
# array(['Sales', nan, 'Engineering', 'Support', 'Marketing', 'HR'],
#       dtype=object)

# %% [markdown]
# **Department names is now Standarized**

# %%
df
# Out:
#        Serial No                                    ID  \
# 0              0  1e407ff9-6255-489d-a0de-34135d4f74bd
# 1              1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2              2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3              3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 4              4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90
# ...          ...                                   ...
# 10995       6523  07c223be-03e6-4f70-a2b5-86df778cc61a
# 10996       9785  da8a6bbc-5026-4630-848d-f64e80dac56c
# 10997       7826  ed19c966-d6d8-4047-b410-b6e595a39340
# 10998       7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
# 10999       7107  fc25a38a-5747-46eb-b6d3-7173f8255809
#
#                           Name   Age                      Email  Join Date  \
# 0                Hunter Thomas  25.0         xlopez@hotmail.com        NaT
# 1                 Jeremy Irwin  90.0            Jillian Jenkins 2022-07-07
# 2      Jennifer Hammondquickly  66.0            jscottgreen.biz 2023-11-21
# ...

# %% [markdown]
# ****
# ## 5. Handle Missing Values:
# ****
# **Plan: check the occurence of Null and there patterns**

# %%
df.isnull().sum()
# Out:
# Serial No        0
# ID               0
# Name          2333
# Age           1747
# Email         1269
# Join Date     4010
# Salary        2239
# Department    2255
# dtype: int64

# %%
useless_data = df['Name'].isna() & df['Age'].isna()

# %%
df[useless_data]
# Out:
#        Serial No                                    ID Name  Age Email  \
# 18            18  05e36d3f-6422-4329-80b2-1fd3543ee254  NaN  NaN   NaN
# 19            19  a8b6e8e3-f2f2-42c6-b2d7-2bbfd9b91125  NaN  NaN   NaN
# 24            24  3f741e1f-f781-463e-a12a-871d3866c711  NaN  NaN   NaN
# 30            30  754d31ea-7749-4d29-b0f1-a8fb908d541c  NaN  NaN   NaN
# 40            40  9aa93a07-4dac-4c44-bdde-0424c118041f  NaN  NaN   NaN
# ...          ...                                   ...  ...  ...   ...
# 10971       3899  8e75cd6c-861f-4e8a-89e2-50f0ee6642a5  NaN  NaN   NaN
# 10975       4685  2adebc64-900d-431a-93cd-118de4bb6eb7  NaN  NaN   NaN
# 10978       3054  1ea7f125-698d-49dc-a97a-955b4dc4fc9b  NaN  NaN   NaN
# 10988       6403  4edd1e6e-cfb5-4300-9c74-e9642836e134  NaN  NaN   NaN
# 10995       6523  07c223be-03e6-4f70-a2b5-86df778cc61a  NaN  NaN   NaN
#
#       Join Date  Salary Department
# 18          NaT     NaN        NaN
# 19          NaT     NaN        NaN
# ...

# %%
df = df.drop(df[useless_data].index)

# %%
df.describe()
# Out:
#          Serial No          Age                      Join Date         Salary
# count  9669.000000  9253.000000                           6944    8703.000000
# mean   5032.677630    54.162650  2022-03-13 08:13:32.903225856   89903.243632
# min       0.000000    18.000000            2020-01-01 00:00:00   24655.136613
# 25%    2539.000000    36.000000            2021-02-05 00:00:00   59761.000000
# 50%    5059.000000    54.000000            2022-03-14 00:00:00   89266.746493
# 75%    7539.000000    72.000000            2023-04-21 00:00:00  119492.000000
# max    9999.000000    90.000000            2024-06-13 00:00:00  176156.206747
# std    2887.161449    21.072919                            NaN   34880.283179

# %% [markdown]
# Mean and Median are approximately same in Age and Salary

# %% [markdown]
# #### Handle missing values in Age and Salary

# %%
from sklearn.impute import SimpleImputer

# %% [markdown]
# Filling the NULL with Mean value of that particular column:

# %%
numerical_columns = df.select_dtypes(include='float64').columns
numerical_columns
imputer = SimpleImputer(strategy='mean')
df[numerical_columns] = imputer.fit_transform(df[numerical_columns])

# %% [markdown]
# #### Handle missing values in Department

# %%
imputer = SimpleImputer(strategy='most_frequent')
# Apply the imputer to the 'Department' column
df[['Department']] = imputer.fit_transform(df[['Department']])

# %% [markdown]
# #### Handle missing values in Join Date

# %%
# Calculate the mode date
mode_date = df['Join Date'].mode()
#print(mode_date)
print(mode_date[0])
# Out:
# 2022-03-31 00:00:00

# %%
print(df['Join Date'].isnull().sum())
# Out:
# 2725

# %%
df['Join Date'] = df['Join Date'].fillna(mode_date[0])

# %%
df
# Out:
#        Serial No                                    ID  \
# 0              0  1e407ff9-6255-489d-a0de-34135d4f74bd
# 1              1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2              2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3              3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 4              4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90
# ...          ...                                   ...
# 10994       3978  6714ff24-3600-4c6e-8eed-5b4224bd9e44
# 10996       9785  da8a6bbc-5026-4630-848d-f64e80dac56c
# 10997       7826  ed19c966-d6d8-4047-b410-b6e595a39340
# 10998       7648  783b36b4-d09f-46c9-8a52-7ff96b80863e
# 10999       7107  fc25a38a-5747-46eb-b6d3-7173f8255809
#
#                           Name       Age                      Email  \
# 0                Hunter Thomas  25.00000         xlopez@hotmail.com
# 1                 Jeremy Irwin  90.00000            Jillian Jenkins
# 2      Jennifer Hammondquickly  66.00000            jscottgreen.biz
# ...

# %% [markdown]
# ****
# ## 6. Remove Duplicates:
# Plan:
# 1. Check the duplicates in rows
# 2. check the duplicates within the rows group by specific columns names
# ****

# %%
df.duplicated().sum()
# Out:
# 191

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (9478, 8)

# %%
## 3. Remove Duplicates:
df[df.duplicated(subset=['Serial No', 'ID'], keep=False)]
# Out:
#        Serial No                                    ID                 Name  \
# 14            14  9b83a5e5-9516-493f-86f8-d6c445edb501      Nicole Cardenas
# 66            66  cfd80c1c-5a2a-47d3-9c4f-a8dbe7e1b836         Carmen Green
# 80            80  bc03dd30-8836-4161-a3a0-140ab79ead86      William Jonesin
# 89            89  1759df8c-3f9b-4963-854f-c9023b076b3b          Karen Chase
# 105          105  280bef03-b76c-40c9-ab35-cef5d79a669c                  NaN
# ...          ...                                   ...                  ...
# 10992       7429  749e71e0-f852-4749-bae3-b59b9c5a9e77                  NaN
# 10993       9510  796f8c0b-15a4-475c-bb02-ac892df0c746  Shelley Hopkinslive
# 10996       9785  da8a6bbc-5026-4630-848d-f64e80dac56c     Steven Armstrong
# 10997       7826  ed19c966-d6d8-4047-b410-b6e595a39340   Stephanie Riossell
# 10998       7648  783b36b4-d09f-46c9-8a52-7ff96b80863e       Bonnie Benitez
#
# ...

# %%
df[df['ID'] == '8da4b611-0237-4b52-87a6-26b3a6773002']
# Out:
#        Serial No                                    ID                   Name  \
# 122          122  8da4b611-0237-4b52-87a6-26b3a6773002             Neil Moore
# 10380        122  8da4b611-0237-4b52-87a6-26b3a6773002  Neil Mooreenvironment
#
#             Age                         Email  Join Date   Salary Department
# 122    54.16265   wrightchristopherbenson.net 2022-03-25  98559.0      Sales
# 10380  54.16265  wrightchristopher@benson.net 2022-03-31  98559.0      Sales

# %%
df[df['ID'] == '57214c37-40d2-4ab3-8d2a-e027c721dd51']
# Out:
#        Serial No                                    ID                Name  \
# 168          168  57214c37-40d2-4ab3-8d2a-e027c721dd51         Karla Bowen
# 10440        168  57214c37-40d2-4ab3-8d2a-e027c721dd51  Karla Bowensociety
#
#         Age                    Email  Join Date   Salary Department
# 168    46.0  justinevans@hotmail.com 2022-03-31  52578.0         HR
# 10440  46.0  justinevans@hotmail.com 2022-04-09  52578.0         HR

# %%
df = df.drop_duplicates(subset=['Serial No', 'ID'], keep='first')

# %%
df[df['ID'] == '9b7f9c12-9dba-40f5-91b4-db145484e8ac']
# Out:
#      Serial No                                    ID                  Name  \
# 175        175  9b7f9c12-9dba-40f5-91b4-db145484e8ac  George Fullermission
#
#       Age                                   Email  Join Date   Salary  \
# 175  82.0  stephaniethompson@chavez-alexander.com 2020-07-28  37687.0
#
#     Department
# 175      Sales

# %%
df[df.duplicated(subset=['Serial No', 'ID', 'Name'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [Serial No, ID, Name, Age, Email, Join Date, Salary, Department]
# Index: []

# %%
df[df.duplicated(subset=['Name','Age','Department'], keep=False)]
# Out:
#       Serial No                                    ID             Name   Age  \
# 306         306  5d3dfbc8-22ec-494c-93e1-f1f5c7340261  Alexander Jones  75.0
# 1039       1039  74818f8e-7968-425c-83e1-3b039d557e0f       Andrew Lee  65.0
# 4527       4527  f06f12e1-93c4-44c6-a3db-6f98c9790046  Alexander Jones  75.0
# 9760       9760  da9a435d-d749-4a2e-be8e-332409962062       Andrew Lee  65.0
#
#                                   Email  Join Date         Salary   Department
# 306   rebeccaking@alexander-chapman.com 2021-07-23  110392.000000  Engineering
# 1039         jorgerodriguez@ray-cox.com 2020-04-20  144206.000000      Support
# 4527                  amy11@hotmail.com 2022-03-31  103619.000000  Engineering
# 9760     johnsullivan@williams-wang.com 2021-07-16   89903.243632      Support

# %%
df[df['Name'] == 'Andrew Lee']
# Out:
#       Serial No                                    ID        Name   Age  \
# 1039       1039  74818f8e-7968-425c-83e1-3b039d557e0f  Andrew Lee  65.0
# 9139       9139  bcb3bcd6-cbad-4ede-884d-033aa469a396  Andrew Lee  74.0
# 9760       9760  da9a435d-d749-4a2e-be8e-332409962062  Andrew Lee  65.0
#
#                                Email  Join Date         Salary   Department
# 1039      jorgerodriguez@ray-cox.com 2020-04-20  144206.000000      Support
# 9139          marktaylor@hotmail.com 2021-10-12   57400.143856  Engineering
# 9760  johnsullivan@williams-wang.com 2021-07-16   89903.243632      Support

# %% [markdown]
# There joining date, mail id, salary is different these commonality cannot be considered duplicate

# %%
df['Email'].value_counts()
# Out:
# Email
# mmurphy@gmail.com                 2
# ehunter@gmail.com                 2
# fwilliams@yahoo.com               2
# james53@yahoo.com                 2
# jennifer82@gmail.com              2
#                                  ..
# millerbridget@wright-tran.info    1
# phall@myers.com                   1
# carladaniels@edwards-knox.biz     1
# mccoyjason@shepard.com            1
# cjones@yahoo.com                  1
# Name: count, Length: 8822, dtype: int64

# %%
df[df['Email'] == 'daniellewilliams@gmail.com']
# Out:
#       Serial No                                    ID              Name   Age  \
# 22           22  88e92fab-a06c-4c53-a59a-699bf8a583b5  Curtis Parkerlot  36.0
# 2550       2550  4604d647-6f8d-484b-a331-82f2fb02f707    Jennifer Yoder  25.0
#
#                            Email  Join Date        Salary Department
# 22    daniellewilliams@gmail.com 2023-12-08  89903.243632         HR
# 2550  daniellewilliams@gmail.com 2021-04-19  42642.000000         HR

# %%
df[df.duplicated(subset=['Email'], keep=False)]
# Out:
#       Serial No                                    ID  \
# 22           22  88e92fab-a06c-4c53-a59a-699bf8a583b5
# 276         276  aba32fa8-ebc0-45da-91d4-537af59b2325
# 279         279  d417afc2-97ac-409f-8aff-ee7397720966
# 388         388  4b5a1295-460e-4b89-a354-02727ada7f03
# 597         597  a420bc8a-51c2-4dee-b010-5251c4bfd79c
# 702         702  9b9f203d-be64-46e4-98ea-afdab2cc2416
# 1351       1351  ef5ecb2d-6a7f-4e86-97f0-f525184623c9
# 1791       1791  cd6ef6f0-907e-4936-99b4-1747f2a17fd8
# 1927       1927  9267a701-c03e-4312-9cc2-525949356193
# 1943       1943  69f561a2-eceb-4aef-b34d-99b114ef741a
# 2043       2043  df466675-4ce4-48c4-8855-c46dde71de73
# 2215       2215  46eb67dd-b8e3-4414-ab15-90bc1086e3f8
# 2257       2257  f6cfb1de-2fa6-451f-be34-1c47f8b6d023
# 2315       2315  1be0f421-a3f1-43a8-b1da-d05e2c5aac10
# 2333       2333  5fa73f2c-f515-4eba-93a4-ba38967c4217
# 2550       2550  4604d647-6f8d-484b-a331-82f2fb02f707
# ...

# %%
df = df.drop_duplicates(subset=['Email'], keep='first')

# %%
df[df['Email'] == 'daniellewilliams@gmail.com']
# Out:
#     Serial No                                    ID              Name   Age  \
# 22         22  88e92fab-a06c-4c53-a59a-699bf8a583b5  Curtis Parkerlot  36.0
#
#                          Email  Join Date        Salary Department
# 22  daniellewilliams@gmail.com 2023-12-08  89903.243632         HR

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       Serial No                                    ID  \
# 0             0  1e407ff9-6255-489d-a0de-34135d4f74bd
# 1             1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2             2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3             3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 4             4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90
# ...         ...                                   ...
# 9995       9995  610210a0-e344-4b79-95ce-ff6583d7d8ce
# 9996       9996  eb66531c-901a-4da7-bc60-a4951886b5a8
# 9997       9997  86a83f25-224d-498d-9901-c2e4a49ffbd2
# 9998       9998  9cbba425-6af2-455f-8566-62402de79661
# 9999       9999  ae6eee4d-ca8f-4932-96f1-487230875968
#
#                          Name   Age                              Email  \
# 0               Hunter Thomas  25.0                 xlopez@hotmail.com
# 1                Jeremy Irwin  90.0                    Jillian Jenkins
# 2     Jennifer Hammondquickly  66.0                    jscottgreen.biz
# ...

# %% [markdown]
# ****
# ## 7. Correct Email Formats:
# Plan:
# 1. Format the mail id to "username@domain.com"
# ****

# %%
valid_email_regex = r'^[\w\.-]+@[a-zA-Z\d\.-]+\.(com|info|net|org|biz)$'
invalid_emails = df[~df['Email'].str.match(valid_email_regex)]

# %%
invalid_emails
# Out:
#       Serial No                                    ID  \
# 1             1  379f55b8-87d5-4739-a146-7400b78c24d1
# 2             2  18261368-dfa1-47f0-afc6-bddf45926b07
# 3             3  ae7cf7cf-17cf-4c8b-9c44-4f61a9a238e5
# 6             6  c4892dbb-2554-4ce1-8f11-f6597d7f6782
# 7             7  465e625b-f924-4061-8356-c7e3130f7118
# ...         ...                                   ...
# 9984       9984  a7a3ae17-9fd9-4f41-809b-b33e842eff59
# 9985       9985  df3b2d2b-9439-473b-8e6c-b784ea1dc430
# 9988       9988  974d789f-4780-4490-b8fc-9f27105a8cf7
# 9990       9990  bfb737b9-4663-4a45-9735-677d70a8b0f0
# 9992       9992  7a3c8d2b-3f5c-41ee-854e-6f4378ec41b0
#
#                          Name   Age                               Email  \
# 1                Jeremy Irwin  90.0                     Jillian Jenkins
# 2     Jennifer Hammondquickly  66.0                     jscottgreen.biz
# 3             Sydney Taylorso  39.0                  luke56gonzalez.com
# ...

# %% [markdown]
# **These Email entries cannot be considered as a proper entry**

# %%
df = df[df['Email'].str.match(valid_email_regex)]

# %%
df
# Out:
#       Serial No                                    ID               Name  \
# 0             0  1e407ff9-6255-489d-a0de-34135d4f74bd      Hunter Thomas
# 4             4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90          Julia Lee
# 5             5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c        Lisa Bailey
# 8             8  12cc2f16-d641-402e-b22b-3332bafc4f1d                NaN
# 9             9  d06f507d-62e5-4bd6-a252-4e60e109d324         Jay Fisher
# ...         ...                                   ...                ...
# 9995       9995  610210a0-e344-4b79-95ce-ff6583d7d8ce    David Lambalone
# 9996       9996  eb66531c-901a-4da7-bc60-a4951886b5a8        Karen Yoder
# 9997       9997  86a83f25-224d-498d-9901-c2e4a49ffbd2  Anthony Rasmussen
# 9998       9998  9cbba425-6af2-455f-8566-62402de79661       Nicole Moore
# 9999       9999  ae6eee4d-ca8f-4932-96f1-487230875968     Steven Gilbert
#
#        Age                              Email  Join Date         Salary  \
# ...

# %% [markdown]
# ****
# ## 8. Cleaning Name Field
# Plan:
# 1. Clear all the Null values
# 2. Remove Title in name if any
# 3. remove the extraneous words if any
# ****

# %%
df = df.dropna(subset=['Name'])

# %%
df
# Out:
#       Serial No                                    ID               Name  \
# 0             0  1e407ff9-6255-489d-a0de-34135d4f74bd      Hunter Thomas
# 4             4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90          Julia Lee
# 5             5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c        Lisa Bailey
# 9             9  d06f507d-62e5-4bd6-a252-4e60e109d324         Jay Fisher
# 10           10  d5fe9321-49cf-4f14-ac96-7aea1204247b       Craig Conway
# ...         ...                                   ...                ...
# 9995       9995  610210a0-e344-4b79-95ce-ff6583d7d8ce    David Lambalone
# 9996       9996  eb66531c-901a-4da7-bc60-a4951886b5a8        Karen Yoder
# 9997       9997  86a83f25-224d-498d-9901-c2e4a49ffbd2  Anthony Rasmussen
# 9998       9998  9cbba425-6af2-455f-8566-62402de79661       Nicole Moore
# 9999       9999  ae6eee4d-ca8f-4932-96f1-487230875968     Steven Gilbert
#
#        Age                              Email  Join Date         Salary  \
# ...

# %% [markdown]
# **handle name with titles**

# %%
name_title_pattern = r'\b(?:Mr\.|Mrs\.|Ms\.|Dr\.|Miss\.)\s'
# Filter rows where names contain titles
names_with_titles = df[df['Name'].str.contains(name_title_pattern, na=False)]

print("Names with titles:")
print(names_with_titles)
# Out:
# Names with titles:
#       Serial No                                    ID  \
# 63           63  6e50ff2b-ee84-4ba1-adc1-88aced745fff
# 74           74  ee302c6d-5164-4b86-bad1-b9624b44c130
# 90           90  7edc8e0d-ef5f-4bed-88e3-f4c696dc318d
# 225         225  50aa4a9b-0245-4537-8602-bc416a102426
# 269         269  d13d6f3e-dff7-4fa9-b5ee-9a613dd6b04a
# ...         ...                                   ...
# 9613       9613  529eff83-407f-4237-a1a9-b26150320067
# 9685       9685  ccb13ab9-7fe8-4abd-95c3-d6f52661ef85
# 9702       9702  9a0b6e90-d54d-4f3b-a2b6-e0cb00c96858
# 9904       9904  675192e0-950a-45ae-9e7b-4ce815c08d74
# 9936       9936  6dcfb2c6-9a39-4a55-82a7-5f5b39138e7d
#
#                                  Name       Age  \
# 63              Mrs. Sheri Duffyparty  38.00000
# 74                Mr. Larry Mcpherson  23.00000
# 90         Mrs. Betty Robinsonmission  50.00000
# 225              Mrs. Karen Robertson  87.00000
# ...

# %%
import re

# replace titles in a string
def replace_titles(name):
    if isinstance(name, str):  # Check if name is a string
        return re.sub(name_title_pattern, '', name)
    else:
        return name  # Return NaN or non-string values unchanged :Just in case

# Apply the replace_titles function to the 'Name' column
df.loc[:,'Name'] = df['Name'].apply(replace_titles)

# %%
df[df['Name'] == "Sheri Duffyparty"]
# Out:
#     Serial No                                    ID              Name   Age  \
# 63         63  6e50ff2b-ee84-4ba1-adc1-88aced745fff  Sheri Duffyparty  38.0
#
#                    Email  Join Date   Salary Department
# 63  woodmadison@rice.com 2023-05-06  93430.0  Marketing

# %%
df[df['Name'].str.contains("Ann Heath", na=False)]
# Out:
#       Serial No                                    ID          Name   Age  \
# 9613       9613  529eff83-407f-4237-a1a9-b26150320067  Ann Heath MD  49.0
#
#                           Email  Join Date   Salary Department
# 9613  leonarddunlap@cameron.com 2022-06-30  95084.0  Marketing

# %% [markdown]
# **handle 3rd name**

# %%
# Function to remove the third word from names with length 3
def remove_third_word(name):
    if isinstance(name, str):  # Check if the value is a string
        words = name.split()  # Split the name into words
        if len(words) == 3:  # Check if the name has exactly 3 words
            del words[2]  # Remove the third word
            return ' '.join(words)  # Join the remaining words back together
    return name  # Return the name unchanged for non-string values or names with different lengths

# Apply the remove_third_word function to the 'Name' column
df.loc[:,'Name'] = df['Name'].apply(remove_third_word)

# %%
df[df['Name'].str.contains("Ann Heath", na=False)]
# Out:
#       Serial No                                    ID       Name   Age  \
# 9613       9613  529eff83-407f-4237-a1a9-b26150320067  Ann Heath  49.0
#
#                           Email  Join Date   Salary Department
# 9613  leonarddunlap@cameron.com 2022-06-30  95084.0  Marketing

# %% [markdown]
# **handling few extraneous words.**

# %%
df[df['Name'].str.contains("Taylor", na=False)]
# Out:
#       Serial No                                    ID  \
# 113         113  dcb5f899-d8cb-4598-a62a-10662b75cec9
# 235         235  6b49a4ad-0d13-4978-88f9-39fc95db1d07
# 313         313  76cae4ae-f411-4850-90e6-22ad3827e379
# 1574       1574  116e5e89-b6d1-4c0c-bf9e-a7db34d70188
# 1702       1702  eca3334a-a7d3-43fe-8052-fecb96f03dd7
# 2018       2018  70c982c3-614e-4c4b-ade0-31434e42b879
# 2524       2524  a02b8603-b5d4-418f-9a0c-ecda89ce9c3c
# 2537       2537  7b0a865f-ef21-4910-a9f9-6708a77f4142
# 2921       2921  04dea3fe-f6b5-4232-ac84-4b401a567af8
# 3225       3225  fc1b80ae-4058-4330-83c4-dd7e75d660df
# 3252       3252  7c077fc0-d5ed-447f-abed-b6fcc462af79
# 3280       3280  c4103369-b9a5-40d4-99fb-020dd3fd6823
# 3281       3281  0b028173-2378-4ec5-af45-fd39bd3197d9
# 4053       4053  9163f813-6db6-43bd-bb20-0195831b1967
# 4638       4638  ffc24ab0-52e9-4fa6-9d5a-9fcca3934fcc
# 4748       4748  0231ac0d-dbf3-4e60-af61-53369b9cbe88
# ...

# %%
last_names = df['Name'].str.split().str[-1]

# %%
last_names[last_names.str.contains("Taylor", na=False)]
# Out:
# 113             Taylor
# 235     Taylordaughter
# 313             Taylor
# 1702            Taylor
# 2018            Taylor
# 2524        Taylorfive
# 2537            Taylor
# 3280            Taylor
# 4053            Taylor
# 4638            Taylor
# 4748            Taylor
# 4972            Taylor
# 5082            Taylor
# 5099       Taylorcheck
# 5375            Taylor
# 5567            Taylor
# 5669    Taylordaughter
# 5732            Taylor
# 6234            Taylor
# 6329      Taylordecade
# 6753         Taylorcan
# 6861            Taylor
# 7008            Taylor
# 7185     Taylormedical
# 7276            Taylor
# 7294            Taylor
# 7303            Taylor
# 7540        Taylorblue
# 7597            Taylor
# 8137            Taylor
# 8225            Taylor
# 8950            Taylor
# 9119            Taylor
# 9877            Taylor
# Name: Name, dtype: object

# %%
# Get the counts of each name
name_counts = last_names.value_counts()
total_names = name_counts[name_counts > 0].index.tolist()

# Filter names that are repeated more than once
repeated_names = name_counts[name_counts > 2].index.tolist()
# Filter the DataFrame to include only rows with repeated names
valid_surname = last_names[last_names.isin(repeated_names)]

# %%
valid_surname = list(set(valid_surname))
valid_surname = sorted(valid_surname, key=len, reverse=True)
valid_surname
# Out:
# ['Christensen',
#  'Fitzpatrick',
#  'Cunningham',
#  'Washington',
#  'Livingston',
#  'Montgomery',
#  'Mccullough',
#  'Richardson',
#  'Singleton',
#  'Christian',
#  'Contreras',
#  'Gallagher',
#  'Macdonald',
#  'Wilkinson',
#  'Mcconnell',
#  'Underwood',
#  'Alexander',
#  'Mccormick',
#  'Donaldson',
#  'Carpenter',
#  'Schneider',
#  'Robertson',
#  'Fernandez',
#  'Hernandez',
#  'Dominguez',
#  'Henderson',
#  'Jefferson',
#  'Wilkerson',
#  'Patterson',
#  'Dickerson',
#  'Armstrong',
#  'Stevenson',
#  'Nicholson',
#  'Gutierrez',
#  'Rodriguez',
#  'Blanchard',
#  'Castillo',
#  'Mcdonald',
#  'Robinson',
#  'Campbell',
#  'Mcdaniel',
#  'Crawford',
#  'Anderson',
#  'Bradford',
#  'Gonzalez',
#  'Whitaker',
#  'Erickson',
#  'Chandler',
#  'Martinez',
#  'Ferguson',
#  'Delacruz',
#  'Figueroa',
#  'Morrison',
#  'Richards',
#  'Fletcher',
#  'Davidson',
#  'Reynolds',
#  'Marshall',
#  'Mckenzie',
#  'Williams',
#  'Johnston',
#  'Copeland',
#  'Schwartz',
# ...

# %% [markdown]
# **total surnames:**

# %%
check_surname_in_list = [surname for surname in total_names if "Duffy" in surname]
check_surname_in_list
# Out:
# ['Duffy', 'Duffyparty']

# %% [markdown]
# **filtered surnames:**

# %%
check_surname_in_list = [surname for surname in valid_surname if "Johnson" in surname]
check_surname_in_list
# Out:
# ['Johnson']

# %%
check_surname_in_list = [surname for surname in valid_surname if "Lamb" in surname]
check_surname_in_list
# Out:
# ['Lambert', 'Lamb']

# %%
df
# Out:
#       Serial No                                    ID               Name  \
# 0             0  1e407ff9-6255-489d-a0de-34135d4f74bd      Hunter Thomas
# 4             4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90          Julia Lee
# 5             5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c        Lisa Bailey
# 9             9  d06f507d-62e5-4bd6-a252-4e60e109d324         Jay Fisher
# 10           10  d5fe9321-49cf-4f14-ac96-7aea1204247b       Craig Conway
# ...         ...                                   ...                ...
# 9995       9995  610210a0-e344-4b79-95ce-ff6583d7d8ce    David Lambalone
# 9996       9996  eb66531c-901a-4da7-bc60-a4951886b5a8        Karen Yoder
# 9997       9997  86a83f25-224d-498d-9901-c2e4a49ffbd2  Anthony Rasmussen
# 9998       9998  9cbba425-6af2-455f-8566-62402de79661       Nicole Moore
# 9999       9999  ae6eee4d-ca8f-4932-96f1-487230875968     Steven Gilbert
#
#        Age                              Email  Join Date         Salary  \
# ...

# %% [markdown]
# **some more filtering needed:**
#
# **checking the common in (total_names and valid_surname) to get the final surname list**

# %%
#total_names = ['taylordaughter', 'taylorphysical', 'lambert', 'lambsoft', 'mooney']
#valid_surname = ['taylor', 'lambert', 'Hernandez', 'lamb']

# Initialize an empty list to store converted elements
converted_list = []

# Iterate through list1
for item in total_names:
    # Check if any valid surname is a substring of the item
    for surname in valid_surname:
        if surname in item:
            converted_list.append(surname)
            break  # Stop searching for other surnames once a match is found
    else:
        # If no match is found, keep the original item
        converted_list.append(item)
converted_list = list(set(converted_list))

# %%
##### this is the final list of SURNAMES Yuhuuuuuuuu
converted_list = sorted(converted_list, key=len, reverse=True)
check_surname_in_list = [surname for surname in converted_list if "Mooney" in surname]
check_surname_in_list
# Out:
# ['Mooney']

# %%
df
# Out:
#       Serial No                                    ID               Name  \
# 0             0  1e407ff9-6255-489d-a0de-34135d4f74bd      Hunter Thomas
# 4             4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90          Julia Lee
# 5             5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c        Lisa Bailey
# 9             9  d06f507d-62e5-4bd6-a252-4e60e109d324         Jay Fisher
# 10           10  d5fe9321-49cf-4f14-ac96-7aea1204247b       Craig Conway
# ...         ...                                   ...                ...
# 9995       9995  610210a0-e344-4b79-95ce-ff6583d7d8ce    David Lambalone
# 9996       9996  eb66531c-901a-4da7-bc60-a4951886b5a8        Karen Yoder
# 9997       9997  86a83f25-224d-498d-9901-c2e4a49ffbd2  Anthony Rasmussen
# 9998       9998  9cbba425-6af2-455f-8566-62402de79661       Nicole Moore
# 9999       9999  ae6eee4d-ca8f-4932-96f1-487230875968     Steven Gilbert
#
#        Age                              Email  Join Date         Salary  \
# ...

# %%
df['Name New'] = df['Name'].copy()
# Out:
# C:\Users\naasa\AppData\Local\Temp\ipykernel_24708\4105923548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name New'] = df['Name'].copy()

# %%
df
# Out:
#       Serial No                                    ID               Name  \
# 0             0  1e407ff9-6255-489d-a0de-34135d4f74bd      Hunter Thomas
# 4             4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90          Julia Lee
# 5             5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c        Lisa Bailey
# 9             9  d06f507d-62e5-4bd6-a252-4e60e109d324         Jay Fisher
# 10           10  d5fe9321-49cf-4f14-ac96-7aea1204247b       Craig Conway
# ...         ...                                   ...                ...
# 9995       9995  610210a0-e344-4b79-95ce-ff6583d7d8ce    David Lambalone
# 9996       9996  eb66531c-901a-4da7-bc60-a4951886b5a8        Karen Yoder
# 9997       9997  86a83f25-224d-498d-9901-c2e4a49ffbd2  Anthony Rasmussen
# 9998       9998  9cbba425-6af2-455f-8566-62402de79661       Nicole Moore
# 9999       9999  ae6eee4d-ca8f-4932-96f1-487230875968     Steven Gilbert
#
#        Age                              Email  Join Date         Salary  \
# ...

# %% [markdown]
# **copy the name to a new column and trimming out the extraneous words from the surname**

# %%
# Initialize an empty list to store the matched parts
matched_parts = []

# Iterate through the DataFrame
for index, row in df.iterrows():
    # Extract the last name from the 'name' column
    last_name = row['Name New'].split()[-1]
    
    # Iterate through the surname list
    for s in converted_list:
        # Check if the current surname is a substring of the last name
        if s in last_name:
            # Store the matched part
            matched_parts.append(s)
            # Replace the last name with the matched part
            df.at[index, 'Name New'] = row['Name New'].rsplit(' ', 1)[0] + ' ' + s
            # Exit the loop since we found a match
            break

# %%
index_of_name_column = df.columns.get_loc('Name')
salary_column = df.pop('Name New')  # Remove 'Salary' column from DataFrame
df.insert(index_of_name_column, 'Name New', salary_column)  # Insert 'Salary' column at the desired position

# %%
df[df['Name'] == "Sheri Duffyparty"]
# Out:
#     Serial No                                    ID     Name New  \
# 63         63  6e50ff2b-ee84-4ba1-adc1-88aced745fff  Sheri Duffy
#
#                 Name   Age                 Email  Join Date   Salary  \
# 63  Sheri Duffyparty  38.0  woodmadison@rice.com 2023-05-06  93430.0
#
#    Department
# 63  Marketing

# %%
df[df['Name'].str.contains('Johnson', case=False)]
# Out:
#       Serial No                                    ID          Name New  \
# 195         195  70c4681f-68fb-490e-8fc0-4c5237eafd04   Frances Johnson
# 232         232  55626b6a-2705-4505-9bd9-765d9ebc6f85    Brooke Johnson
# 426         426  fc605cff-2d94-45ad-abd2-fe79ebc6cd29     James Johnson
# 539         539  703f45f8-5106-4064-9964-0a47457aee46      Jack Johnson
# 562         562  8f2132e6-f9f5-481b-9189-503283242fb0  Margaret Johnson
# ...         ...                                   ...               ...
# 9259       9259  e883cbdc-d2c4-42a2-b59f-0880cbfbb1ca     Scott Johnson
# 9346       9346  3a97dbb2-e401-4126-8160-704c4b91e4ac      Jody Johnson
# 9656       9656  57a9b85b-c0b4-4c53-b194-d3fc4f8bef57   Melissa Johnson
# 9898       9898  949fb2f0-c450-405d-a1b6-b27dcd9fd5fb    Hannah Johnson
# 9911       9911  68501623-f32c-417f-bd05-5045360ff55a    Ashley Johnson
#
#                       Name       Age                           Email  \
# ...

# %%
df[df['Name'].str.contains('Taylordaughter', case=False)]
# Out:
#       Serial No                                    ID          Name New  \
# 235         235  6b49a4ad-0d13-4978-88f9-39fc95db1d07    Patrick Taylor
# 5669       5669  aee49e56-c968-4bee-a271-08102f6f159f  Cassandra Taylor
#
#                           Name   Age                   Email  Join Date  \
# 235     Patrick Taylordaughter  40.0     zmueller@miller.org 2022-08-15
# 5669  Cassandra Taylordaughter  51.0  tristanmiles@gmail.com 2022-03-31
#
#            Salary Department
# 235   126289.0000    Support
# 5669   46090.3008    Support

# %%
df[df['Name'].str.contains('Lamb', case=False)]
# Out:
#       Serial No                                    ID         Name New  \
# 2155       2155  6fd8bbfe-06d8-4c0c-81d0-c45bbbc39ace  Jacqueline Lamb
# 2606       2606  1f9f77d7-9b3b-4001-bccd-253cd76bddc2  Charles Lambert
# 4570       4570  e245e55b-eda6-489a-8c36-c2e96c9de08c   Nicole Lambert
# 4887       4887  cbe59eed-c879-48fe-b011-2b8efd1e96c3   Martin Lambert
# 4921       4921  1b1fa6d0-8027-469a-b8ad-036c42643ae3  Jeffrey Lambert
# 5396       5396  5083c325-c6d0-4ad9-9038-c7a7b44d2e3a       Laura Lamb
# 6590       6590  00cbba4c-3155-4be5-90bb-f8a9d181fceb    Jonathan Lamb
# 7585       7585  8f010636-ce37-4276-920c-c2bd7f6aa9e0      Javier Lamb
# 7669       7669  c8aa1e91-d712-4397-87a3-1a93230b66e0       Shawn Lamb
# 7974       7974  11fe1d96-97b1-4302-a359-a42d146daac3      Lee Lambert
# 8352       8352  9c4ef848-cd31-4738-bd26-2c280dc90792    Colin Lambert
# 8640       8640  a970aa00-de6f-4233-b2d7-5def58dc09d4    Tracy Lambert
# ...

# %% [markdown]
# **The Surnames are corrected very accurately**

# %%
df = df.drop(columns=['Name'])
df = df.rename(columns={'Name New': 'Name'})

# %%
df.head()
# Out:
#     Serial No                                    ID           Name   Age  \
# 0           0  1e407ff9-6255-489d-a0de-34135d4f74bd  Hunter Thomas  25.0
# 4           4  14ed3e6a-e0f5-4bbe-8d93-8665267f5c90      Julia Lee  71.0
# 5           5  f92ea13f-24d3-4792-91e4-5b0e07d90c2c    Lisa Bailey  81.0
# 9           9  d06f507d-62e5-4bd6-a252-4e60e109d324     Jay Fisher  44.0
# 10         10  d5fe9321-49cf-4f14-ac96-7aea1204247b   Craig Conway  88.0
#
#                            Email  Join Date         Salary   Department
# 0             xlopez@hotmail.com 2022-03-31   88552.000000        Sales
# 4        figueroakayla@yahoo.com 2022-03-31  143456.000000    Marketing
# 5   milleryvonne@fowler-york.com 2022-03-31  123018.000000      Support
# 9       denisemaynard@jordan.com 2022-12-08   37701.725993           HR
# 10    gerald47@woodard-smith.com 2022-03-31   81214.525972  Engineering

# %% [markdown]
# ****
# ### 9. Check the Salary Column:
# ****

# %%
df.describe()
# Out:
#          Serial No          Age                      Join Date         Salary
# count  5963.000000  5963.000000                           5963    5963.000000
# mean   5009.591648    54.122727  2022-03-16 17:41:35.186986496   90134.626250
# min       0.000000    18.000000            2020-01-01 00:00:00   26233.921419
# 25%    2494.000000    37.000000            2021-07-18 12:00:00   63744.500000
# 50%    5046.000000    54.162650            2022-03-31 00:00:00   89903.243632
# 75%    7515.000000    71.000000            2022-11-05 00:00:00  116642.443828
# max    9999.000000    90.000000            2024-06-12 00:00:00  176156.206747
# std    2887.244181    20.443719                            NaN   33127.155457

# %%
print(f" minimum of salary is {df['Salary'].min()}")
print(f" Maximum of salary is {df['Salary'].max()}")
print(f" Mean of salary is {df['Salary'].mean()}")
# Out:
#  minimum of salary is 26233.921418582304
#  Maximum of salary is 176156.20674749595
#  Mean of salary is 90134.6262495239

# %%
salary_by_department = df.groupby('Department')['Salary'].sum().reset_index()
salary_by_department['Salary'] = salary_by_department['Salary'].apply(lambda x: '{:,.0f}'.format(x))
salary_by_department
# Out:
#     Department       Salary
# 0  Engineering   95,666,812
# 1           HR   94,611,197
# 2    Marketing   96,280,210
# 3        Sales   98,050,745
# 4      Support  152,863,813

# %%
max_salary_index = df['Salary'].idxmax()

# Retrieve the employee with maximum salary and their department
employee_max_salary = df.loc[max_salary_index]
print(f"[{employee_max_salary['Name']}] from Department [{employee_max_salary['Department']}] is paid the Highest Salary [{'{:.6f}'.format(employee_max_salary['Salary'])}]")
# Out:
# [Julie Schultz] from Department [Support] is paid the Highest Salary [176156.206747]

# %% [markdown]
# **Listing the Minimum and Maximum Salary in each deaprtment**

# %%
salary_stats = df.groupby('Department')['Salary'].agg(['min', 'max'])
salary_stats
# Out:
#                       min            max
# Department
# Engineering  26720.412228  174786.876707
# HR           26233.921419  169568.430118
# Marketing    28192.807828  175218.428249
# Sales        27187.979971  165560.143182
# Support      27976.146050  176156.206747

# %%
###ensure it is ready for analysis. 
#df = df.drop(columns=['Name','Serial No','ID'])
df.isnull().sum()
# Out:
# Serial No     0
# ID            0
# Name          0
# Age           0
# Email         0
# Join Date     0
# Salary        0
# Department    0
# dtype: int64

# %% [markdown]
# ### 10. Save the dataSet

# %%
df.to_csv('cleaned_dataset.csv', index=False)
